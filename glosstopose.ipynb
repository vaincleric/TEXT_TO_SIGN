# %%
import os
import pandas as pd
import json
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import LabelEncoder
from torch.nn.utils.rnn import pad_sequence

class GlossKeypointDataset(Dataset):
    def __init__(self, data_dir):
        self.data_dir = data_dir
        self.csv_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')]

        self.glosses = []
        self.sequences = []

        # Parse each CSV file
        for csv_file in self.csv_files:
            gloss_name = os.path.splitext(csv_file)[0]
            csv_path = os.path.join(data_dir, csv_file)

            try:
                df = pd.read_csv(csv_path)

                # Parse keypoints in each row
                keypoint_sequences = []
                for _, row in df.iterrows():
                    try:
                        keypoints_dict = json.loads(row['keypoints'])
                        keypoints = keypoints_dict['pose']

                        # Validate keypoints
                        if keypoints and isinstance(keypoints, list) and len(keypoints) > 0:
                            # Convert keypoints to flat list of floats
                            keypoints_flat = [float(k) for k in keypoints]
                            if len(keypoints_flat) == output_dim:  # Make sure dimensions match
                                keypoint_sequences.append(keypoints_flat)
                    except (json.JSONDecodeError, KeyError, ValueError) as e:
                        print(f"Error processing row in {csv_file}: {e}")
                        continue

                # Only add sequences if we have valid keypoints
                if len(keypoint_sequences) > 0:
                    self.glosses.append(gloss_name)
                    self.sequences.append(keypoint_sequences)
                else:
                    print(f"Warning: No valid keypoints found in {csv_file}")

            except Exception as e:
                print(f"Error processing file {csv_file}: {e}")
                continue

        if len(self.glosses) == 0:
            raise ValueError("No valid data found in the dataset")

        # Label encode the glosses
        self.label_encoder = LabelEncoder()
        self.encoded_glosses = self.label_encoder.fit_transform(self.glosses)

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        gloss = self.encoded_glosses[idx]
        keypoint_sequence = self.sequences[idx]

        # Convert to tensor and ensure proper dimensions
        keypoint_sequence = torch.tensor(keypoint_sequence, dtype=torch.float32)
        return torch.tensor(gloss, dtype=torch.long), keypoint_sequence

def collate_fn(batch):
    # Separate glosses and sequences
    glosses, sequences = zip(*batch)

    # Stack glosses
    glosses = torch.stack(glosses)

    # Get sequence lengths
    lengths = [seq.size(0) for seq in sequences]

    # Pad sequences
    if all(len(seq) > 0 for seq in sequences):
        padded_sequences = pad_sequence(sequences, batch_first=True, padding_value=0.0)
    else:
        raise ValueError("Found empty sequence in batch")

    return glosses, padded_sequences, torch.tensor(lengths)

class LSTMGlossToKeypointModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, gloss, seq_lengths):
        # Embedding layer
        embedded = self.embedding(gloss).unsqueeze(1)  # [batch_size, 1, embedding_dim]

        # LSTM layer
        lstm_out, _ = self.lstm(embedded)  # [batch_size, 1, hidden_dim]

        # Get final hidden state
        final_hidden = lstm_out.squeeze(1)  # [batch_size, hidden_dim]

        # Output layer
        output = self.fc(final_hidden)  # [batch_size, output_dim]
        return output

# Parameters
data_dir = '/content/drive/MyDrive/gloss_selected'
embedding_dim = 128
hidden_dim = 256
output_dim = 33  # Ensure this matches your keypoint dimension
batch_size = 16
learning_rate = 0.001
num_epochs = 50

# Create dataset and dataloader
try:
    dataset = GlossKeypointDataset(data_dir)
    dataloader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=True,
        collate_fn=collate_fn,
        drop_last=True  # Drop incomplete last batch
    )
except Exception as e:
    print(f"Error creating dataset: {e}")
    raise

# Initialize model
vocab_size = len(dataset.label_encoder.classes_)
model = LSTMGlossToKeypointModel(vocab_size, embedding_dim, hidden_dim, output_dim)

# Loss function and optimizer
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Training Loop
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    batch_count = 0

    try:
        for batch_idx, (gloss, keypoint_seq, lengths) in enumerate(dataloader):
            # Move tensors to device
            gloss = gloss.to(device)
            keypoint_seq = keypoint_seq.to(device)

            # Zero gradients
            optimizer.zero_grad()

            # Forward pass
            predictions = model(gloss, lengths)

            # Compute loss (using first frame of sequence as target)
            loss = criterion(predictions, keypoint_seq[:, 0, :])

            # Backward pass
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            batch_count += 1

            if batch_idx % 10 == 0:
                print(f"Epoch {epoch+1}/{num_epochs}, Batch {batch_idx}, Loss: {loss.item():.4f}")

    except Exception as e:
        print(f"Error during training: {e}")
        continue

    avg_loss = total_loss / batch_count if batch_count > 0 else float('inf')
    print(f"Epoch {epoch + 1}/{num_epochs}, Average Loss: {avg_loss:.4f}")

# Save the trained model
try:
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'epoch': num_epochs,
        'vocab_size': vocab_size,
        'embedding_dim': embedding_dim,
        'hidden_dim': hidden_dim,
        'output_dim': output_dim
    }, 'lstm_gloss_to_keypoint_model.pth')
except Exception as e:
    print(f"Error saving model: {e}")
# Out:
# Error processing file improve.csv: float() argument must be a string or a real number, not 'list'
# Error processing file spit.csv: float() argument must be a string or a real number, not 'list'
# Error processing file fold.csv: float() argument must be a string or a real number, not 'list'
# Error processing file discuss.csv: float() argument must be a string or a real number, not 'list'
# Error processing file include.csv: float() argument must be a string or a real number, not 'list'
# Error processing file spoon.csv: float() argument must be a string or a real number, not 'list'
# Error processing file rough.csv: float() argument must be a string or a real number, not 'list'
# Error processing file plan.csv: float() argument must be a string or a real number, not 'list'
# Error processing file rubber.csv: float() argument must be a string or a real number, not 'list'
# Error processing file bee.csv: float() argument must be a string or a real number, not 'list'
# Error processing file increase.csv: float() argument must be a string or a real number, not 'list'
# Error processing file follow.csv: float() argument must be a string or a real number, not 'list'
# Error processing file spray.csv: float() argument must be a string or a real number, not 'list'
# Error processing file plant.csv: float() argument must be a string or a real number, not 'list'
# Error processing file mirror.csv: float() argument must be a string or a real number, not 'list'
# Error processing file closet.csv: float() argument must be a string or a real number, not 'list'
# Error processing file disgust.csv: float() argument must be a string or a real number, not 'list'
# Error processing file beer.csv: float() argument must be a string or a real number, not 'list'
# Error processing file rude.csv: float() argument must be a string or a real number, not 'list'
# Error processing file clothes.csv: float() argument must be a string or a real number, not 'list'
# Error processing file spread.csv: float() argument must be a string or a real number, not 'list'
# Error processing file before.csv: float() argument must be a string or a real number, not 'list'
# Error processing file independent.csv: float() argument must be a string or a real number, not 'list'
# Error processing file ruin.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dismiss.csv: float() argument must be a string or a real number, not 'list'
# Error processing file mistake.csv: float() argument must be a string or a real number, not 'list'
# Error processing file spring.csv: float() argument must be a string or a real number, not 'list'
# Error processing file india.csv: float() argument must be a string or a real number, not 'list'
# Error processing file rule.csv: float() argument must be a string or a real number, not 'list'
# Error processing file cloud.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sprint.csv: float() argument must be a string or a real number, not 'list'
# Error processing file run.csv: float() argument must be a string or a real number, not 'list'
# Error processing file misunderstand.csv: float() argument must be a string or a real number, not 'list'
# Error processing file disturb.csv: float() argument must be a string or a real number, not 'list'
# Error processing file clueless.csv: float() argument must be a string or a real number, not 'list'
# Error processing file beg.csv: float() argument must be a string or a real number, not 'list'
# Error processing file square.csv: float() argument must be a string or a real number, not 'list'
# Error processing file beginning.csv: float() argument must be a string or a real number, not 'list'
# Error processing file rush.csv: float() argument must be a string or a real number, not 'list'
# Error processing file mock.csv: float() argument must be a string or a real number, not 'list'
# Error processing file clumsy.csv: float() argument must be a string or a real number, not 'list'
# Error processing file forest.csv: float() argument must be a string or a real number, not 'list'
# Error processing file squeeze.csv: float() argument must be a string or a real number, not 'list'
# Error processing file russia.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dive.csv: float() argument must be a string or a real number, not 'list'
# Error processing file behavior.csv: float() argument must be a string or a real number, not 'list'
# Error processing file plenty.csv: float() argument must be a string or a real number, not 'list'
# Error processing file information.csv: float() argument must be a string or a real number, not 'list'
# Error processing file coach.csv: float() argument must be a string or a real number, not 'list'
# Error processing file inform.csv: float() argument must be a string or a real number, not 'list'
# Error processing file squirrel.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stadium.csv: float() argument must be a string or a real number, not 'list'
# Error processing file behind.csv: float() argument must be a string or a real number, not 'list'
# Error processing file monday.csv: float() argument must be a string or a real number, not 'list'
# Error processing file forgive.csv: float() argument must be a string or a real number, not 'list'
# Error processing file division.csv: float() argument must be a string or a real number, not 'list'
# Error processing file money.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pneumonia.csv: float() argument must be a string or a real number, not 'list'
# Error processing file belief.csv: float() argument must be a string or a real number, not 'list'
# Error processing file safe.csv: float() argument must be a string or a real number, not 'list'
# Error processing file divorce.csv: float() argument must be a string or a real number, not 'list'
# Error processing file for.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pocket.csv: float() argument must be a string or a real number, not 'list'
# Error processing file innocent.csv: float() argument must be a string or a real number, not 'list'
# Error processing file staff.csv: float() argument must be a string or a real number, not 'list'
# Error processing file monster.csv: float() argument must be a string or a real number, not 'list'
# Error processing file insect.csv: float() argument must be a string or a real number, not 'list'
# Error processing file salad.csv: float() argument must be a string or a real number, not 'list'
# Error processing file former.csv: float() argument must be a string or a real number, not 'list'
# Error processing file salary.csv: float() argument must be a string or a real number, not 'list'
# Error processing file form.csv: float() argument must be a string or a real number, not 'list'
# Error processing file bell.csv: float() argument must be a string or a real number, not 'list'
# Error processing file doctor.csv: float() argument must be a string or a real number, not 'list'
# Error processing file better.csv: float() argument must be a string or a real number, not 'list'
# Error processing file below.csv: float() argument must be a string or a real number, not 'list'
# Error processing file coffee.csv: float() argument must be a string or a real number, not 'list'
# Error processing file belt.csv: float() argument must be a string or a real number, not 'list'
# Error processing file benefit.csv: float() argument must be a string or a real number, not 'list'
# Error processing file beside.csv: float() argument must be a string or a real number, not 'list'
# Error processing file best.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dollar.csv: float() argument must be a string or a real number, not 'list'
# Error processing file inspect.csv: float() argument must be a string or a real number, not 'list'
# Error processing file fox.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dolphin.csv: float() argument must be a string or a real number, not 'list'
# Error processing file month.csv: float() argument must be a string or a real number, not 'list'
# Error processing file monthly.csv: float() argument must be a string or a real number, not 'list'
# Error processing file france.csv: float() argument must be a string or a real number, not 'list'
# Error processing file freeway.csv: float() argument must be a string or a real number, not 'list'
# Error processing file moon.csv: float() argument must be a string or a real number, not 'list'
# Error processing file moose.csv: float() argument must be a string or a real number, not 'list'
# Error processing file polar bear.csv: float() argument must be a string or a real number, not 'list'
# Error processing file freeze.csv: float() argument must be a string or a real number, not 'list'
# Error processing file french fries.csv: float() argument must be a string or a real number, not 'list'
# Error processing file insurance.csv: float() argument must be a string or a real number, not 'list'
# Error processing file french.csv: float() argument must be a string or a real number, not 'list'
# Error processing file salute.csv: float() argument must be a string or a real number, not 'list'
# Error processing file police.csv: float() argument must be a string or a real number, not 'list'
# Error processing file policeman.csv: float() argument must be a string or a real number, not 'list'
# Error processing file same.csv: float() argument must be a string or a real number, not 'list'
# Error processing file interesting.csv: float() argument must be a string or a real number, not 'list'
# Error processing file morning.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stamp.csv: float() argument must be a string or a real number, not 'list'
# Error processing file mosquito.csv: float() argument must be a string or a real number, not 'list'
# Error processing file standard.csv: float() argument must be a string or a real number, not 'list'
# Error processing file policy.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sandwich.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stand.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stare.csv: float() argument must be a string or a real number, not 'list'
# Error processing file saturday.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sauce.csv: float() argument must be a string or a real number, not 'list'
# Error processing file star.csv: float() argument must be a string or a real number, not 'list'
# Error processing file poor.csv: float() argument must be a string or a real number, not 'list'
# Error processing file popcorn.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sausage.csv: float() argument must be a string or a real number, not 'list'
# Error processing file start.csv: float() argument must be a string or a real number, not 'list'
# Error processing file statistics.csv: float() argument must be a string or a real number, not 'list'
# Error processing file save.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stay.csv: float() argument must be a string or a real number, not 'list'
# Error processing file steal.csv: float() argument must be a string or a real number, not 'list'
# Error processing file steel.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stepfather.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sticky.csv: float() argument must be a string or a real number, not 'list'
# Error processing file still.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sting.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stink.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stir.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stitch.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stomach.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stop.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dangerous.csv: float() argument must be a string or a real number, not 'list'
# Error processing file date.csv: float() argument must be a string or a real number, not 'list'
# Error processing file degree.csv: float() argument must be a string or a real number, not 'list'
# Error processing file deny.csv: float() argument must be a string or a real number, not 'list'
# Error processing file depressed.csv: float() argument must be a string or a real number, not 'list'
# Error processing file desert.csv: float() argument must be a string or a real number, not 'list'
# Error processing file design.csv: float() argument must be a string or a real number, not 'list'
# Error processing file destroy.csv: float() argument must be a string or a real number, not 'list'
# Error processing file devil.csv: float() argument must be a string or a real number, not 'list'
# Error processing file diaper.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dice.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dinosaur.csv: float() argument must be a string or a real number, not 'list'
# Error processing file uncle.csv: float() argument must be a string or a real number, not 'list'
# Error processing file director.csv: float() argument must be a string or a real number, not 'list'
# Error processing file straw.csv: float() argument must be a string or a real number, not 'list'
# Error processing file disconnect.csv: float() argument must be a string or a real number, not 'list'
# Error processing file under.csv: float() argument must be a string or a real number, not 'list'
# Error processing file disgusted.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dissolve.csv: float() argument must be a string or a real number, not 'list'
# Error processing file street.csv: float() argument must be a string or a real number, not 'list'
# Error processing file divide.csv: float() argument must be a string or a real number, not 'list'
# Error processing file story.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dizzy.csv: float() argument must be a string or a real number, not 'list'
# Error processing file understand.csv: float() argument must be a string or a real number, not 'list'
# Error processing file document.csv: float() argument must be a string or a real number, not 'list'
# Error processing file straight.csv: float() argument must be a string or a real number, not 'list'
# Error processing file don't want.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stress.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stretch.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dormitory.csv: float() argument must be a string or a real number, not 'list'
# Error processing file double.csv: float() argument must be a string or a real number, not 'list'
# Error processing file doubt.csv: float() argument must be a string or a real number, not 'list'
# Error processing file draw.csv: float() argument must be a string or a real number, not 'list'
# Error processing file unique.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dress.csv: float() argument must be a string or a real number, not 'list'
# Error processing file strict.csv: float() argument must be a string or a real number, not 'list'
# Error processing file drop.csv: float() argument must be a string or a real number, not 'list'
# Error processing file united states.csv: float() argument must be a string or a real number, not 'list'
# Error processing file due.csv: float() argument must be a string or a real number, not 'list'
# Error processing file structure.csv: float() argument must be a string or a real number, not 'list'
# Error processing file duty.csv: float() argument must be a string or a real number, not 'list'
# Error processing file come here.csv: float() argument must be a string or a real number, not 'list'
# Error processing file scold.csv: float() argument must be a string or a real number, not 'list'
# Error processing file university.csv: float() argument must be a string or a real number, not 'list'
# Error processing file earthquake.csv: float() argument must be a string or a real number, not 'list'
# Error processing file education.csv: float() argument must be a string or a real number, not 'list'
# Error processing file eighteen.csv: float() argument must be a string or a real number, not 'list'
# Error processing file electrician.csv: float() argument must be a string or a real number, not 'list'
# Error processing file elephant.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stubborn.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stuck.csv: float() argument must be a string or a real number, not 'list'
# Error processing file upset.csv: float() argument must be a string or a real number, not 'list'
# Error processing file upstairs.csv: float() argument must be a string or a real number, not 'list'
# Error processing file encourage.csv: float() argument must be a string or a real number, not 'list'
# Error processing file energy.csv: float() argument must be a string or a real number, not 'list'
# Error processing file engage.csv: float() argument must be a string or a real number, not 'list'
# Error processing file use.csv: float() argument must be a string or a real number, not 'list'
# Error processing file erase.csv: float() argument must be a string or a real number, not 'list'
# Error processing file vacant.csv: float() argument must be a string or a real number, not 'list'
# Error processing file event.csv: float() argument must be a string or a real number, not 'list'
# Error processing file everything.csv: float() argument must be a string or a real number, not 'list'
# Error processing file exact.csv: float() argument must be a string or a real number, not 'list'
# Error processing file study.csv: float() argument must be a string or a real number, not 'list'
# Error processing file excited.csv: float() argument must be a string or a real number, not 'list'
# Error processing file excuse.csv: float() argument must be a string or a real number, not 'list'
# Error processing file vacation.csv: float() argument must be a string or a real number, not 'list'
# Error processing file exercise.csv: float() argument must be a string or a real number, not 'list'
# Error processing file vague.csv: float() argument must be a string or a real number, not 'list'
# Error processing file explode.csv: float() argument must be a string or a real number, not 'list'
# Error processing file express.csv: float() argument must be a string or a real number, not 'list'
# Error processing file stupid.csv: float() argument must be a string or a real number, not 'list'
# Error processing file valley.csv: float() argument must be a string or a real number, not 'list'
# Error processing file eyes.csv: float() argument must be a string or a real number, not 'list'
# Error processing file faculty.csv: float() argument must be a string or a real number, not 'list'
# Error processing file value.csv: float() argument must be a string or a real number, not 'list'
# Error processing file famous.csv: float() argument must be a string or a real number, not 'list'
# Error processing file subway.csv: float() argument must be a string or a real number, not 'list'
# Error processing file fast.csv: float() argument must be a string or a real number, not 'list'
# Error processing file fat.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sue.csv: float() argument must be a string or a real number, not 'list'
# Error processing file feedback.csv: float() argument must be a string or a real number, not 'list'
# Error processing file fence.csv: float() argument must be a string or a real number, not 'list'
# Error processing file suffer.csv: float() argument must be a string or a real number, not 'list'
# Error processing file verb.csv: float() argument must be a string or a real number, not 'list'
# Error processing file firefighter.csv: float() argument must be a string or a real number, not 'list'
# Error processing file fishing.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sugar.csv: float() argument must be a string or a real number, not 'list'
# Error processing file flirt.csv: float() argument must be a string or a real number, not 'list'
# Error processing file flower.csv: float() argument must be a string or a real number, not 'list'
# Error processing file flute.csv: float() argument must be a string or a real number, not 'list'
# Error processing file fly.csv: float() argument must be a string or a real number, not 'list'
# Error processing file suggest.csv: float() argument must be a string or a real number, not 'list'
# Error processing file vice president.csv: float() argument must be a string or a real number, not 'list'
# Error processing file fool.csv: float() argument must be a string or a real number, not 'list'
# Error processing file viewpoint.csv: float() argument must be a string or a real number, not 'list'
# Error processing file forbid.csv: float() argument must be a string or a real number, not 'list'
# Error processing file forever.csv: float() argument must be a string or a real number, not 'list'
# Error processing file forget.csv: float() argument must be a string or a real number, not 'list'
# Error processing file fork.csv: float() argument must be a string or a real number, not 'list'
# Error processing file fourth.csv: float() argument must be a string or a real number, not 'list'
# Error processing file free.csv: float() argument must be a string or a real number, not 'list'
# Error processing file summon.csv: float() argument must be a string or a real number, not 'list'
# Error processing file violin.csv: float() argument must be a string or a real number, not 'list'
# Error processing file friendly.csv: float() argument must be a string or a real number, not 'list'
# Error processing file visit.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sunday.csv: float() argument must be a string or a real number, not 'list'
# Error processing file full.csv: float() argument must be a string or a real number, not 'list'
# Error processing file function.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sun.csv: float() argument must be a string or a real number, not 'list'
# Error processing file gallaudet.csv: float() argument must be a string or a real number, not 'list'
# Error processing file gas.csv: float() argument must be a string or a real number, not 'list'
# Error processing file gay.csv: float() argument must be a string or a real number, not 'list'
# Error processing file get up.csv: float() argument must be a string or a real number, not 'list'
# Error processing file ghost.csv: float() argument must be a string or a real number, not 'list'
# Error processing file give up.csv: float() argument must be a string or a real number, not 'list'
# Error processing file golf.csv: float() argument must be a string or a real number, not 'list'
# Error processing file vocabulary.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sunshine.csv: float() argument must be a string or a real number, not 'list'
# Error processing file grab.csv: float() argument must be a string or a real number, not 'list'
# Error processing file superman.csv: float() argument must be a string or a real number, not 'list'
# Error processing file voice.csv: float() argument must be a string or a real number, not 'list'
# Error processing file grapes.csv: float() argument must be a string or a real number, not 'list'
# Error processing file support.csv: float() argument must be a string or a real number, not 'list'
# Error processing file guess.csv: float() argument must be a string or a real number, not 'list'
# Error processing file volleyball.csv: float() argument must be a string or a real number, not 'list'
# Error processing file guilty.csv: float() argument must be a string or a real number, not 'list'
# Error processing file gum.csv: float() argument must be a string or a real number, not 'list'
# Error processing file heap.csv: float() argument must be a string or a real number, not 'list'
# Error processing file hearing.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sure.csv: float() argument must be a string or a real number, not 'list'
# Error processing file hearing aid.csv: float() argument must be a string or a real number, not 'list'
# Error processing file vomit.csv: float() argument must be a string or a real number, not 'list'
# Error processing file heaven.csv: float() argument must be a string or a real number, not 'list'
# Error processing file surface.csv: float() argument must be a string or a real number, not 'list'
# Error processing file hockey.csv: float() argument must be a string or a real number, not 'list'
# Error processing file honey.csv: float() argument must be a string or a real number, not 'list'
# Error processing file surgeon.csv: float() argument must be a string or a real number, not 'list'
# Error processing file hug.csv: float() argument must be a string or a real number, not 'list'
# Error processing file vote.csv: float() argument must be a string or a real number, not 'list'
# Error processing file identify.csv: float() argument must be a string or a real number, not 'list'
# Error processing file impact.csv: float() argument must be a string or a real number, not 'list'
# Error processing file waiter.csv: float() argument must be a string or a real number, not 'list'
# Error processing file surgery.csv: float() argument must be a string or a real number, not 'list'
# Error processing file individual.csv: float() argument must be a string or a real number, not 'list'
# Error processing file infection.csv: float() argument must be a string or a real number, not 'list'
# Error processing file influence.csv: float() argument must be a string or a real number, not 'list'
# Error processing file inside.csv: float() argument must be a string or a real number, not 'list'
# Error processing file inspire.csv: float() argument must be a string or a real number, not 'list'
# Error processing file surrender.csv: float() argument must be a string or a real number, not 'list'
# Error processing file instead.csv: float() argument must be a string or a real number, not 'list'
# Error processing file institute.csv: float() argument must be a string or a real number, not 'list'
# Error processing file interest.csv: float() argument must be a string or a real number, not 'list'
# Error processing file interpreter.csv: float() argument must be a string or a real number, not 'list'
# Error processing file interview.csv: float() argument must be a string or a real number, not 'list'
# Error processing file wait.csv: float() argument must be a string or a real number, not 'list'
# Error processing file invite.csv: float() argument must be a string or a real number, not 'list'
# Error processing file involve.csv: float() argument must be a string or a real number, not 'list'
# Error processing file ireland.csv: float() argument must be a string or a real number, not 'list'
# Error processing file wake up.csv: float() argument must be a string or a real number, not 'list'
# Error processing file iron.csv: float() argument must be a string or a real number, not 'list'
# Error processing file jewelry.csv: float() argument must be a string or a real number, not 'list'
# Error processing file jewish.csv: float() argument must be a string or a real number, not 'list'
# Error processing file suspect.csv: float() argument must be a string or a real number, not 'list'
# Error processing file suspend.csv: float() argument must be a string or a real number, not 'list'
# Error processing file kangaroo.csv: float() argument must be a string or a real number, not 'list'
# Error processing file key.csv: float() argument must be a string or a real number, not 'list'
# Error processing file kick.csv: float() argument must be a string or a real number, not 'list'
# Error processing file kid.csv: float() argument must be a string or a real number, not 'list'
# Error processing file king.csv: float() argument must be a string or a real number, not 'list'
# Error processing file walk.csv: float() argument must be a string or a real number, not 'list'
# Error processing file swallow.csv: float() argument must be a string or a real number, not 'list'
# Error processing file last.csv: float() argument must be a string or a real number, not 'list'
# Error processing file last week.csv: float() argument must be a string or a real number, not 'list'
# Error processing file last year.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sweater.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sweden.csv: float() argument must be a string or a real number, not 'list'
# Error processing file wander.csv: float() argument must be a string or a real number, not 'list'
# Error processing file law.csv: float() argument must be a string or a real number, not 'list'
# Error processing file lead.csv: float() argument must be a string or a real number, not 'list'
# Error processing file league.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sweep.csv: float() argument must be a string or a real number, not 'list'
# Error processing file lend.csv: float() argument must be a string or a real number, not 'list'
# Error processing file lesbian.csv: float() argument must be a string or a real number, not 'list'
# Error processing file letter.csv: float() argument must be a string or a real number, not 'list'
# Error processing file a.csv: float() argument must be a string or a real number, not 'list'
# Error processing file b.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sweetheart.csv: float() argument must be a string or a real number, not 'list'
# Error processing file d.csv: float() argument must be a string or a real number, not 'list'
# Error processing file e.csv: float() argument must be a string or a real number, not 'list'
# Error processing file f.csv: float() argument must be a string or a real number, not 'list'
# Error processing file g.csv: float() argument must be a string or a real number, not 'list'
# Error processing file war.csv: float() argument must be a string or a real number, not 'list'
# Error processing file i.csv: float() argument must be a string or a real number, not 'list'
# Error processing file j.csv: float() argument must be a string or a real number, not 'list'
# Error processing file k.csv: float() argument must be a string or a real number, not 'list'
# Error processing file m.csv: float() argument must be a string or a real number, not 'list'
# Error processing file n.csv: float() argument must be a string or a real number, not 'list'
# Error processing file o.csv: float() argument must be a string or a real number, not 'list'
# Error processing file p.csv: float() argument must be a string or a real number, not 'list'
# Error processing file swim.csv: float() argument must be a string or a real number, not 'list'
# Error processing file q.csv: float() argument must be a string or a real number, not 'list'
# Error processing file r.csv: float() argument must be a string or a real number, not 'list'
# Error processing file s.csv: float() argument must be a string or a real number, not 'list'
# Error processing file t.csv: float() argument must be a string or a real number, not 'list'
# Error processing file warm.csv: float() argument must be a string or a real number, not 'list'
# Error processing file u.csv: float() argument must be a string or a real number, not 'list'
# Error processing file v.csv: float() argument must be a string or a real number, not 'list'
# Error processing file w.csv: float() argument must be a string or a real number, not 'list'
# Error processing file swimming.csv: float() argument must be a string or a real number, not 'list'
# Error processing file lettuce.csv: float() argument must be a string or a real number, not 'list'
# Error processing file lie.csv: float() argument must be a string or a real number, not 'list'
# Error processing file warn.csv: float() argument must be a string or a real number, not 'list'
# Error processing file light.csv: float() argument must be a string or a real number, not 'list'
# Error processing file linguistics.csv: float() argument must be a string or a real number, not 'list'
# Error processing file wash.csv: float() argument must be a string or a real number, not 'list'
# Error processing file lonely.csv: float() argument must be a string or a real number, not 'list'
# Error processing file swimsuit.csv: float() argument must be a string or a real number, not 'list'
# Error processing file lousy.csv: float() argument must be a string or a real number, not 'list'
# Error processing file lucky.csv: float() argument must be a string or a real number, not 'list'
# Error processing file machine.csv: float() argument must be a string or a real number, not 'list'
# Error processing file washington.csv: float() argument must be a string or a real number, not 'list'
# Error processing file magic.csv: float() argument must be a string or a real number, not 'list'
# Error processing file manage.csv: float() argument must be a string or a real number, not 'list'
# Error processing file swing.csv: float() argument must be a string or a real number, not 'list'
# Error processing file marry.csv: float() argument must be a string or a real number, not 'list'
# Error processing file match.csv: float() argument must be a string or a real number, not 'list'
# Error processing file measure.csv: float() argument must be a string or a real number, not 'list'
# Error processing file waste.csv: float() argument must be a string or a real number, not 'list'
# Error processing file switzerland.csv: float() argument must be a string or a real number, not 'list'
# Error processing file medicine.csv: float() argument must be a string or a real number, not 'list'
# Error processing file memorize.csv: float() argument must be a string or a real number, not 'list'
# Error processing file mention.csv: float() argument must be a string or a real number, not 'list'
# Error processing file watch.csv: float() argument must be a string or a real number, not 'list'
# Error processing file mind.csv: float() argument must be a string or a real number, not 'list'
# Error processing file waterfall.csv: float() argument must be a string or a real number, not 'list'
# Error processing file minute.csv: float() argument must be a string or a real number, not 'list'
# Error processing file symbol.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sympathy.csv: float() argument must be a string or a real number, not 'list'
# Error processing file miss.csv: float() argument must be a string or a real number, not 'list'
# Error processing file mix.csv: float() argument must be a string or a real number, not 'list'
# Error processing file monkey.csv: float() argument must be a string or a real number, not 'list'
# Error processing file table.csv: float() argument must be a string or a real number, not 'list'
# Error processing file most.csv: float() argument must be a string or a real number, not 'list'
# Error processing file water.csv: float() argument must be a string or a real number, not 'list'
# Error processing file motivate.csv: float() argument must be a string or a real number, not 'list'
# Error processing file watermelon.csv: float() argument must be a string or a real number, not 'list'
# Error processing file mouth.csv: float() argument must be a string or a real number, not 'list'
# Error processing file move.csv: float() argument must be a string or a real number, not 'list'
# Error processing file napkin.csv: float() argument must be a string or a real number, not 'list'
# Error processing file network.csv: float() argument must be a string or a real number, not 'list'
# Error processing file take turns.csv: float() argument must be a string or a real number, not 'list'
# Error processing file way.csv: float() argument must be a string or a real number, not 'list'
# Error processing file niece.csv: float() argument must be a string or a real number, not 'list'
# Error processing file nine.csv: float() argument must be a string or a real number, not 'list'
# Error processing file nineteen.csv: float() argument must be a string or a real number, not 'list'
# Error processing file take up.csv: float() argument must be a string or a real number, not 'list'
# Error processing file normal.csv: float() argument must be a string or a real number, not 'list'
# Error processing file weak.csv: float() argument must be a string or a real number, not 'list'
# Error processing file notice.csv: float() argument must be a string or a real number, not 'list'
# Error processing file nut.csv: float() argument must be a string or a real number, not 'list'
# Error processing file tale.csv: float() argument must be a string or a real number, not 'list'
# Error processing file obsess.csv: float() argument must be a string or a real number, not 'list'
# Error processing file wear.csv: float() argument must be a string or a real number, not 'list'
# Error processing file once.csv: float() argument must be a string or a real number, not 'list'
# Error processing file opinion.csv: float() argument must be a string or a real number, not 'list'
# Error processing file talent.csv: float() argument must be a string or a real number, not 'list'
# Error processing file weather.csv: float() argument must be a string or a real number, not 'list'
# Error processing file order.csv: float() argument must be a string or a real number, not 'list'
# Error processing file overlook.csv: float() argument must be a string or a real number, not 'list'
# Error processing file overwhelm.csv: float() argument must be a string or a real number, not 'list'
# Error processing file owl.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pack.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pants.csv: float() argument must be a string or a real number, not 'list'
# Error processing file parallel.csv: float() argument must be a string or a real number, not 'list'
# Error processing file talk.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pass.csv: float() argument must be a string or a real number, not 'list'
# Error processing file wedding.csv: float() argument must be a string or a real number, not 'list'
# Error processing file patient.csv: float() argument must be a string or a real number, not 'list'
# Error processing file peanut butter (1).csv: float() argument must be a string or a real number, not 'list'
# Error processing file peanut butter.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pear (1).csv: float() argument must be a string or a real number, not 'list'
# Error processing file pear.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pennsylvania.csv: float() argument must be a string or a real number, not 'list'
# Error processing file period.csv: float() argument must be a string or a real number, not 'list'
# Error processing file wednesday.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pet.csv: float() argument must be a string or a real number, not 'list'
# Error processing file philadelphia.csv: float() argument must be a string or a real number, not 'list'
# Error processing file tall.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pick.csv: float() argument must be a string or a real number, not 'list'
# Error processing file tan.csv: float() argument must be a string or a real number, not 'list'
# Error processing file plate.csv: float() argument must be a string or a real number, not 'list'
# Error processing file player.csv: float() argument must be a string or a real number, not 'list'
# Error processing file weekend.csv: float() argument must be a string or a real number, not 'list'
# Error processing file plus.csv: float() argument must be a string or a real number, not 'list'
# Error processing file taste.csv: float() argument must be a string or a real number, not 'list'
# Error processing file point.csv: float() argument must be a string or a real number, not 'list'
# Error processing file polite.csv: float() argument must be a string or a real number, not 'list'
# Error processing file week.csv: float() argument must be a string or a real number, not 'list'
# Error processing file politics.csv: float() argument must be a string or a real number, not 'list'
# Error processing file poop.csv: float() argument must be a string or a real number, not 'list'
# Error processing file popular.csv: float() argument must be a string or a real number, not 'list'
# Error processing file weekly.csv: float() argument must be a string or a real number, not 'list'
# Error processing file positive.csv: float() argument must be a string or a real number, not 'list'
# Error processing file teacher.csv: float() argument must be a string or a real number, not 'list'
# Error processing file teach.csv: float() argument must be a string or a real number, not 'list'
# Error processing file principal.csv: float() argument must be a string or a real number, not 'list'
# Error processing file weigh.csv: float() argument must be a string or a real number, not 'list'
# Error processing file weight.csv: float() argument must be a string or a real number, not 'list'
# Error processing file promise.csv: float() argument must be a string or a real number, not 'list'
# Error processing file promote.csv: float() argument must be a string or a real number, not 'list'
# Error processing file proof.csv: float() argument must be a string or a real number, not 'list'
# Error processing file protect.csv: float() argument must be a string or a real number, not 'list'
# Error processing file provide.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pumpkin.csv: float() argument must be a string or a real number, not 'list'
# Error processing file punish.csv: float() argument must be a string or a real number, not 'list'
# Error processing file tea.csv: float() argument must be a string or a real number, not 'list'
# Error processing file puzzled.csv: float() argument must be a string or a real number, not 'list'
# Error processing file quality.csv: float() argument must be a string or a real number, not 'list'
# Error processing file welcome.csv: float() argument must be a string or a real number, not 'list'
# Error processing file team.csv: float() argument must be a string or a real number, not 'list'
# Error processing file rake.csv: float() argument must be a string or a real number, not 'list'
# Error processing file recent.csv: float() argument must be a string or a real number, not 'list'
# Error processing file west.csv: float() argument must be a string or a real number, not 'list'
# Error processing file refuse.csv: float() argument must be a string or a real number, not 'list'
# Error processing file tease.csv: float() argument must be a string or a real number, not 'list'
# Error processing file regular.csv: float() argument must be a string or a real number, not 'list'
# Error processing file relationship.csv: float() argument must be a string or a real number, not 'list'
# Error processing file relief.csv: float() argument must be a string or a real number, not 'list'
# Error processing file technology.csv: float() argument must be a string or a real number, not 'list'
# Error processing file remote control.csv: float() argument must be a string or a real number, not 'list'
# Error processing file remove.csv: float() argument must be a string or a real number, not 'list'
# Error processing file replace.csv: float() argument must be a string or a real number, not 'list'
# Error processing file resign.csv: float() argument must be a string or a real number, not 'list'
# Error processing file resist.csv: float() argument must be a string or a real number, not 'list'
# Error processing file teeth.csv: float() argument must be a string or a real number, not 'list'
# Error processing file responsibility.csv: float() argument must be a string or a real number, not 'list'
# Error processing file telephone.csv: float() argument must be a string or a real number, not 'list'
# Error processing file ridiculous.csv: float() argument must be a string or a real number, not 'list'
# Error processing file roommate.csv: float() argument must be a string or a real number, not 'list'
# Error processing file telescope.csv: float() argument must be a string or a real number, not 'list'
# Error processing file satisfy.csv: float() argument must be a string or a real number, not 'list'
# Error processing file wheelchair.csv: float() argument must be a string or a real number, not 'list'
# Error processing file second.csv: float() argument must be a string or a real number, not 'list'
# Error processing file seem.csv: float() argument must be a string or a real number, not 'list'
# Error processing file senate.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sensitive.csv: float() argument must be a string or a real number, not 'list'
# Error processing file television.csv: float() argument must be a string or a real number, not 'list'
# Error processing file serious.csv: float() argument must be a string or a real number, not 'list'
# Error processing file settle.csv: float() argument must be a string or a real number, not 'list'
# Error processing file several.csv: float() argument must be a string or a real number, not 'list'
# Error processing file tell.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sew.csv: float() argument must be a string or a real number, not 'list'
# Error processing file shop.csv: float() argument must be a string or a real number, not 'list'
# Error processing file shoulder.csv: float() argument must be a string or a real number, not 'list'
# Error processing file show.csv: float() argument must be a string or a real number, not 'list'
# Error processing file shy.csv: float() argument must be a string or a real number, not 'list'
# Error processing file where.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sign.csv: float() argument must be a string or a real number, not 'list'
# Error processing file single.csv: float() argument must be a string or a real number, not 'list'
# Error processing file which.csv: float() argument must be a string or a real number, not 'list'
# Error processing file siren.csv: float() argument must be a string or a real number, not 'list'
# Error processing file temperature.csv: float() argument must be a string or a real number, not 'list'
# Error processing file situation.csv: float() argument must be a string or a real number, not 'list'
# Error processing file temple.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sixteen.csv: float() argument must be a string or a real number, not 'list'
# ...
# Error processing file mechanic.csv: float() argument must be a string or a real number, not 'list'
# Error processing file choice.csv: float() argument must be a string or a real number, not 'list'
# Error processing file human.csv: float() argument must be a string or a real number, not 'list'
# Error processing file choir.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sorry.csv: float() argument must be a string or a real number, not 'list'
# Error processing file fine.csv: float() argument must be a string or a real number, not 'list'
# Error processing file soul.csv: float() argument must be a string or a real number, not 'list'
# Error processing file humble.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dictionary.csv: float() argument must be a string or a real number, not 'list'
# Error processing file choke.csv: float() argument must be a string or a real number, not 'list'
# Error processing file philosophy.csv: float() argument must be a string or a real number, not 'list'
# Error processing file rich.csv: float() argument must be a string or a real number, not 'list'
# Error processing file phone.csv: float() argument must be a string or a real number, not 'list'
# Error processing file die.csv: float() argument must be a string or a real number, not 'list'
# Error processing file meet.csv: float() argument must be a string or a real number, not 'list'
# Error processing file choose.csv: float() argument must be a string or a real number, not 'list'
# Error processing file fingerspell.csv: float() argument must be a string or a real number, not 'list'
# Error processing file ride.csv: float() argument must be a string or a real number, not 'list'
# Error processing file finish.csv: float() argument must be a string or a real number, not 'list'
# Error processing file photographer.csv: float() argument must be a string or a real number, not 'list'
# Error processing file different.csv: float() argument must be a string or a real number, not 'list'
# Error processing file hungry.csv: float() argument must be a string or a real number, not 'list'
# Error processing file difficult.csv: float() argument must be a string or a real number, not 'list'
# Error processing file hunt.csv: float() argument must be a string or a real number, not 'list'
# Error processing file hurricane.csv: float() argument must be a string or a real number, not 'list'
# Error processing file right.csv: float() argument must be a string or a real number, not 'list'
# Error processing file phrase.csv: float() argument must be a string or a real number, not 'list'
# Error processing file meeting.csv: float() argument must be a string or a real number, not 'list'
# Error processing file christ.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dig.csv: float() argument must be a string or a real number, not 'list'
# Error processing file fire.csv: float() argument must be a string or a real number, not 'list'
# Error processing file me.csv: float() argument must be a string or a real number, not 'list'
# Error processing file sour.csv: float() argument must be a string or a real number, not 'list'
# Error processing file south america.csv: float() argument must be a string or a real number, not 'list'
# Error processing file baseball.csv: float() argument must be a string or a real number, not 'list'
# Error processing file hurry.csv: float() argument must be a string or a real number, not 'list'
# Error processing file first.csv: float() argument must be a string or a real number, not 'list'
# Error processing file melody.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dime.csv: float() argument must be a string or a real number, not 'list'
# Error processing file ring.csv: float() argument must be a string or a real number, not 'list'
# Error processing file physician.csv: float() argument must be a string or a real number, not 'list'
# Error processing file melt.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dining room.csv: float() argument must be a string or a real number, not 'list'
# Error processing file hurt.csv: float() argument must be a string or a real number, not 'list'
# Error processing file christmas.csv: float() argument must be a string or a real number, not 'list'
# Error processing file member.csv: float() argument must be a string or a real number, not 'list'
# Error processing file rise.csv: float() argument must be a string or a real number, not 'list'
# Error processing file physics.csv: float() argument must be a string or a real number, not 'list'
# Error processing file south.csv: float() argument must be a string or a real number, not 'list'
# Error processing file husband.csv: float() argument must be a string or a real number, not 'list'
# Error processing file piano.csv: float() argument must be a string or a real number, not 'list'
# Error processing file river.csv: float() argument must be a string or a real number, not 'list'
# Error processing file ice cream.csv: float() argument must be a string or a real number, not 'list'
# Error processing file church.csv: float() argument must be a string or a real number, not 'list'
# Error processing file spain.csv: float() argument must be a string or a real number, not 'list'
# Error processing file road.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dinner.csv: float() argument must be a string or a real number, not 'list'
# Error processing file speak.csv: float() argument must be a string or a real number, not 'list'
# Error processing file roar.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pickle.csv: float() argument must be a string or a real number, not 'list'
# Error processing file message.csv: float() argument must be a string or a real number, not 'list'
# Error processing file diploma.csv: float() argument must be a string or a real number, not 'list'
# Error processing file circle.csv: float() argument must be a string or a real number, not 'list'
# Error processing file bathroom.csv: float() argument must be a string or a real number, not 'list'
# Error processing file robber.csv: float() argument must be a string or a real number, not 'list'
# Error processing file metal.csv: float() argument must be a string or a real number, not 'list'
# Error processing file flag.csv: float() argument must be a string or a real number, not 'list'
# Error processing file idea.csv: float() argument must be a string or a real number, not 'list'
# Error processing file flatter.csv: float() argument must be a string or a real number, not 'list'
# Error processing file battle.csv: float() argument must be a string or a real number, not 'list'
# Error processing file picture.csv: float() argument must be a string or a real number, not 'list'
# Error processing file mexico.csv: float() argument must be a string or a real number, not 'list'
# Error processing file specific.csv: float() argument must be a string or a real number, not 'list'
# Error processing file piece.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dirt.csv: float() argument must be a string or a real number, not 'list'
# Error processing file flexible.csv: float() argument must be a string or a real number, not 'list'
# Error processing file rob.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pie.csv: float() argument must be a string or a real number, not 'list'
# Error processing file robot.csv: float() argument must be a string or a real number, not 'list'
# Error processing file microphone.csv: float() argument must be a string or a real number, not 'list'
# Error processing file beard.csv: float() argument must be a string or a real number, not 'list'
# Error processing file classroom.csv: float() argument must be a string or a real number, not 'list'
# Error processing file speech.csv: float() argument must be a string or a real number, not 'list'
# Error processing file ignore.csv: float() argument must be a string or a real number, not 'list'
# Error processing file microscope.csv: float() argument must be a string or a real number, not 'list'
# Error processing file rock.csv: float() argument must be a string or a real number, not 'list'
# Error processing file disagree.csv: float() argument must be a string or a real number, not 'list'
# Error processing file illegal.csv: float() argument must be a string or a real number, not 'list'
# Error processing file role.csv: float() argument must be a string or a real number, not 'list'
# Error processing file speed.csv: float() argument must be a string or a real number, not 'list'
# Error processing file flood.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pillow.csv: float() argument must be a string or a real number, not 'list'
# Error processing file microwave.csv: float() argument must be a string or a real number, not 'list'
# Error processing file clean.csv: float() argument must be a string or a real number, not 'list'
# Error processing file beautiful.csv: float() argument must be a string or a real number, not 'list'
# Error processing file ill.csv: float() argument must be a string or a real number, not 'list'
# Error processing file roof.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pilot.csv: float() argument must be a string or a real number, not 'list'
# Error processing file floor.csv: float() argument must be a string or a real number, not 'list'
# Error processing file clear.csv: float() argument must be a string or a real number, not 'list'
# Error processing file clever.csv: float() argument must be a string or a real number, not 'list'
# Error processing file disappear.csv: float() argument must be a string or a real number, not 'list'
# Error processing file room.csv: float() argument must be a string or a real number, not 'list'
# Error processing file florida.csv: float() argument must be a string or a real number, not 'list'
# Error processing file middle.csv: float() argument must be a string or a real number, not 'list'
# Error processing file midnight.csv: float() argument must be a string or a real number, not 'list'
# Error processing file because.csv: float() argument must be a string or a real number, not 'list'
# Error processing file discipline.csv: float() argument must be a string or a real number, not 'list'
# Error processing file image.csv: float() argument must be a string or a real number, not 'list'
# Error processing file click.csv: float() argument must be a string or a real number, not 'list'
# Error processing file military.csv: float() argument must be a string or a real number, not 'list'
# Error processing file spill.csv: float() argument must be a string or a real number, not 'list'
# Error processing file spin.csv: float() argument must be a string or a real number, not 'list'
# Error processing file rooster.csv: float() argument must be a string or a real number, not 'list'
# Error processing file milk.csv: float() argument must be a string or a real number, not 'list'
# Error processing file pity.csv: float() argument must be a string or a real number, not 'list'
# Error processing file discount.csv: float() argument must be a string or a real number, not 'list'
# Error processing file climb.csv: float() argument must be a string or a real number, not 'list'
# Error processing file clock.csv: float() argument must be a string or a real number, not 'list'
# Error processing file discover.csv: float() argument must be a string or a real number, not 'list'
# Error processing file rope.csv: float() argument must be a string or a real number, not 'list'
# Error processing file mine.csv: float() argument must be a string or a real number, not 'list'
# Error processing file impossible.csv: float() argument must be a string or a real number, not 'list'
# Error processing file bed.csv: float() argument must be a string or a real number, not 'list'
# Error processing file rose.csv: float() argument must be a string or a real number, not 'list'
# Error processing file minus.csv: float() argument must be a string or a real number, not 'list'
# Error processing file close.csv: float() argument must be a string or a real number, not 'list'
# Error processing file spirit.csv: float() argument must be a string or a real number, not 'list'
# Error processing file abdomen.csv: float() argument must be a string or a real number, not 'list'
# Error processing file able.csv: float() argument must be a string or a real number, not 'list'
# Error processing file about.csv: float() argument must be a string or a real number, not 'list'
# Error processing file bible.csv: float() argument must be a string or a real number, not 'list'
# Error processing file collect.csv: float() argument must be a string or a real number, not 'list'
# Error processing file bike.csv: float() argument must be a string or a real number, not 'list'
# Error processing file accident.csv: float() argument must be a string or a real number, not 'list'
# Error processing file friday.csv: float() argument must be a string or a real number, not 'list'
# Error processing file door.csv: float() argument must be a string or a real number, not 'list'
# Error processing file dorm.csv: float() argument must be a string or a real number, not 'list'
# Error processing file across.csv: float() argument must be a string or a real number, not 'list'
# Error processing file friend.csv: float() argument must be a string or a real number, not 'list'
# Error processing file comb.csv: float() argument must be a string or a real number, not 'list'
# Error processing file international.csv: float() argument must be a string or a real number, not 'list'
# Error processing file motorcycle.csv: float() argument must be a string or a real number, not 'list'
# Error processing file internet.csv: float() argument must be a string or a real number, not 'list'
# Error processing file frog.csv: float() argument must be a string or a real number, not 'list'
# Error processing file position.csv: float() argument must be a string or a real number, not 'list'
# Error processing file active.csv: float() argument must be a string or a real number, not 'list'
# Error processing file comfortable.csv: float() argument must be a string or a real number, not 'list'
# Error processing file birth.csv: float() argument must be a string or a real number, not 'list'
# Error processing file saw.csv: float() argument must be a string or a real number, not 'list'
# Error processing file comma.csv: float() argument must be a string or a real number, not 'list'
# Error processing file mountain.csv: float() argument must be a string or a real number, not 'list'
# Error processing file mouse.csv: float() argument must be a string or a real number, not 'list'
# Error processing file from now on.csv: float() argument must be a string or a real number, not 'list'
# Error processing file command.csv: float() argument must be a string or a real number, not 'list'
# Error processing file interpret.csv: float() argument must be a string or a real number, not 'list'
# Error processing file scan.csv: float() argument must be a string or a real number, not 'list'
# Error creating dataset: No valid data found in the dataset
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-7be4b662f08b> in <cell line: 121>()
#     120 # Create dataset and dataloader
#     121 try:
# --> 122     dataset = GlossKeypointDataset(data_dir)
#     123     dataloader = DataLoader(
#     124         dataset,
#
# <ipython-input-1-7be4b662f08b> in __init__(self, data_dir)
#      53
#      54         if len(self.glosses) == 0:
# ---> 55             raise ValueError("No valid data found in the dataset")
#      56
#      57         # Label encode the glosses
#
# ValueError: No valid data found in the dataset

# %%
import cv2
import numpy as np

# Function to load the model
def load_model(model_path, vocab_size, embedding_dim, hidden_dim, num_keypoints):
    model = LSTMGlossToKeypointModel(vocab_size, embedding_dim, hidden_dim, num_keypoints)
    model.load_state_dict(torch.load(model_path))
    model.eval()
    return model

# Function to visualize keypoints using OpenCV
def visualize_keypoints(keypoints, frame_size=(500, 500)):
    # Create a blank white background
    canvas = np.ones((frame_size[0], frame_size[1], 3), dtype=np.uint8) * 255

    # Scale keypoints to fit the canvas
    scale_factor = frame_size[0] // 2

    # Convert the keypoints to pixel coordinates
    for frame in keypoints:
        for i, point in enumerate(frame):
            x, y = int(point[0] * scale_factor + frame_size[1] // 2), int(point[1] * scale_factor + frame_size[0] // 2)
            cv2.circle(canvas, (x, y), 5, (0, 0, 255), -1)

    # Show the result
    cv2.imshow("Keypoint Visualization", canvas)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Load the saved model
vocab_size = len(dataset.label_encoder.classes_)
model = load_model('lstm_gloss_to_keypoint_model.pth', vocab_size, embedding_dim, hidden_dim, num_keypoints)

# Input a gloss ID for testing
test_gloss_id = torch.tensor([dataset.label_encoder.transform(['test_gloss'])[0]], dtype=torch.long)

# Sequence length (for demonstration purposes, assume 100)
seq_length = torch.tensor([100])

# Predict the keypoints for the test gloss
with torch.no_grad():
    predicted_keypoints = model(test_gloss_id, seq_length)

# Visualize the predicted keypoints
predicted_keypoints = predicted_keypoints.view(-1, num_keypoints, 3).numpy()  # Reshape for visualization
visualize_keypoints(predicted_keypoints)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-e94f75b61468> in <cell line: 93>()
#      91
#      92 # Create dataset and dataloader
# ---> 93 dataset = GlossKeypointDataset(data_dir)
#      94 dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)
#      95
#
# <ipython-input-6-e94f75b61468> in __init__(self, data_dir)
#      44                 # Ensure it's a dictionary of keypoints
#      45                 if isinstance(keypoint_dict, dict):
# ---> 46                     flattened_keypoints = flatten_keypoints(keypoint_dict)
#      47                     keypoint_sequences.append(flattened_keypoints)
#      48                 else:
#
# <ipython-input-6-e94f75b61468> in flatten_keypoints(keypoint_dict)
#      14     flattened = []
#      15     for key, kp in keypoint_dict.items():
# ---> 16         flattened.extend([kp.get('x', 0), kp.get('y', 0), kp.get('z', 0)])  # Include 'z' if available
#      17     return flattened
#      18
#
# AttributeError: 'list' object has no attribute 'get'

# %% [markdown]
# ## Thats what a real goat would do

# %%
pip install numpy pandas tensorflow matplotlib
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (71.0.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.66.2)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split

def load_data(data_folder):
    data = []
    for file in os.listdir(data_folder):
        if file.endswith('_keypoints.csv'):
            df = pd.read_csv(os.path.join(data_folder, file))
            for _, row in df.iterrows():
                keypoints = json.loads(row['keypoints'])
                data.append(keypoints)
    return data

data_folder = r"/content/drive/MyDrive/gloss_selected"
keypoint_data = load_data(data_folder)

# %%
def preprocess_data(keypoint_data, seq_length=30):
    sequences = []
    for keypoints in keypoint_data:
        # Flatten and normalize keypoints
        flat_keypoints = np.array(keypoints).flatten()
        flat_keypoints /= np.max(flat_keypoints)  # Normalize if necessary

        # Create sequences of a fixed length
        for i in range(len(flat_keypoints) - seq_length):
            sequences.append(flat_keypoints[i:i + seq_length])

    return np.array(sequences)

sequences = preprocess_data(keypoint_data)
X, y = sequences[:-1], sequences[1:]  # Predict next frame based on previous frames

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

def build_model(input_shape):
    model = Sequential()
    model.add(LSTM(128, input_shape=input_shape, return_sequences=True))
    model.add(Dropout(0.2))
    model.add(LSTM(64))
    model.add(Dropout(0.2))
    model.add(Dense(input_shape[1], activation='linear'))  # Output layer with linear activation

    model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])
    return model

input_shape = (X.shape[1], X.shape[2])  # (sequence_length, num_features)
model = build_model(input_shape)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-fef3b16a90da> in <cell line: 16>()
#      14     return model
#      15
# ---> 16 input_shape = (X.shape[1], X.shape[2])  # (sequence_length, num_features)
#      17 model = build_model(input_shape)
#
# IndexError: tuple index out of range

# %%
import os
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

def load_gloss_pose_data(csv_directory):
    data = []
    labels = []

    # Iterate through all files in the directory
    for file_name in os.listdir(csv_directory):
        if file_name.endswith(".csv"):
            gloss_word = file_name.split('.')[0]  # Extract gloss word from filename (without extension)
            csv_path = os.path.join(csv_directory, file_name)

            try:
                # Read CSV file containing pose points
                df = pd.read_csv(csv_path)

                # Extract pose points (assuming all columns after the first one are pose points)
                pose_points = df.iloc[:, 1:].values.tolist()  # Convert to list for padding

                # Append the pose points and gloss word to the dataset
                data.append(pose_points)
                labels.append(gloss_word)
            except Exception as e:
                print(f"Error reading {file_name}: {e}")

    # Pad sequences to ensure uniform length
    max_length = max(len(p) for p in data)  # Find the max length of pose sequences
    padded_data = pad_sequences(data, maxlen=max_length, padding='post', dtype='float32')

    return np.array(padded_data), np.array(labels)

# Path to the directory containing the CSV files
csv_directory = "/content/drive/MyDrive/gloss_selected/"

# Load the data
pose_data, gloss_words = load_gloss_pose_data(csv_directory)
print(f"Loaded {len(gloss_words)} gloss words with their corresponding pose points.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-613e691bb13d> in <cell line: 39>()
#      37
#      38 # Load the data
# ---> 39 pose_data, gloss_words = load_gloss_pose_data(csv_directory)
#      40 print(f"Loaded {len(gloss_words)} gloss words with their corresponding pose points.")
#
# <ipython-input-7-613e691bb13d> in load_gloss_pose_data(csv_directory)
#      29     # Pad sequences to ensure uniform length
#      30     max_length = max(len(p) for p in data)  # Find the max length of pose sequences
# ---> 31     padded_data = pad_sequences(data, maxlen=max_length, padding='post', dtype='float32')
#      32
#      33     return np.array(padded_data), np.array(labels)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/data_utils.py in pad_sequences(sequences, maxlen, dtype, padding, truncating, value)
#    1130
#    1131         # check `trunc` has expected shape
# -> 1132         trunc = np.asarray(trunc, dtype=dtype)
#    1133         if trunc.shape[1:] != sample_shape:
#    1134             raise ValueError(
#
# ValueError: could not convert string to float: '{"pose": [[0.5068119764328003, 0.2505396604537964, -0.7745587825775146], [0.517985463142395, 0.21460002660751343, -0.7370471954345703], [0.5256759524345398, 0.21422415971755981, -0.7371422648429871], [0.5333788990974426, 0.21460479497909546, -0.7371224761009216], [0.49168792366981506, 0.2193293571472168, -0.7339509725570679], [0.4814605116844177, 0.22154128551483154, -0.7340691089630127], [0.4723874628543854, 0.22400003671646118, -0.7344253063201904], [0.5447446703910828, 0.23342502117156982, -0.4648835361003876], [0.45668351650238037, 0.24424046277999878, -0.4441893398761749], [0.5234630703926086, 0.2895978093147278, -0.6691169142723083], [0.48945653438568115, 0.29372578859329224, -0.6642863154411316], [0.6267673373222351, 0.45579758286476135, -0.3205034136772156], [0.3758520483970642, 0.45019102096557617, -0.23195897042751312], [0.6451781392097473, 0.7267289757728577, -0.33913204073905945], [0.2912769913673401, 0.7027644515037537, -0.4259045422077179], [0.5183265805244446, 0.8374385833740234, -0.5693448781967163], [0.4124425947666168, 0.7239401340484619, -0.9169824123382568], [0.4761546552181244, 0.897973358631134, -0.6533198952674866], [0.45094573497772217, 0.7644388675689697, -1.0192431211471558], [0.4599469006061554, 0.8718729019165039, -0.6509089469909668], [0.47186845541000366, 0.7213166356086731, -1.0079882144927979], [0.4779302179813385, 0.8461194038391113, -0.5687683820724487], [0.45987871289253235, 0.705...

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import json
import os
from tqdm import tqdm
import pickle

# Mount Google Drive (uncomment if running in Colab)
# from google.colab import drive
# drive.mount('/content/drive')

class GRUSeq2Seq(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers=1):
        super(GRUSeq2Seq, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers

        self.encoder = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.decoder = nn.GRU(hidden_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x, target_len):
        # Ensure input is 3D: (batch_size, sequence_length, input_size)
        if x.dim() == 2:
            x = x.unsqueeze(1)

        _, hidden = self.encoder(x)

        outputs = []
        input = torch.zeros(x.size(0), 1, self.hidden_size).to(x.device)

        for _ in range(target_len):
            output, hidden = self.decoder(input, hidden)
            output = self.fc(output)
            outputs.append(output)
            input = output

        return torch.cat(outputs, dim=1)

class SignLanguageDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

def load_data(folder_path):
    all_glosses = []
    all_keypoints = []

    for filename in tqdm(os.listdir(folder_path), desc="Loading CSV files"):
        if filename.endswith('.csv'):
            file_path = os.path.join(folder_path, filename)
            data = pd.read_csv(file_path)

            gloss = os.path.splitext(filename)[0]
            all_glosses.append(gloss)

            keypoints = json.loads(data['keypoints'].iloc[0])
            all_keypoints.append(keypoints)

    label_encoder = LabelEncoder()
    encoded_glosses = label_encoder.fit_transform(all_glosses)

    keypoints = np.array([np.array(kp['pose']).flatten() for kp in all_keypoints])

    return encoded_glosses, keypoints, label_encoder

def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device):
    model.train()
    for epoch in range(num_epochs):
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)

            optimizer.zero_grad()
            outputs = model(batch_x, batch_y.size(1))
            loss = criterion(outputs, batch_y)
            loss.backward()
            optimizer.step()

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch_x, batch_y in val_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                outputs = model(batch_x, batch_y.size(1))
                val_loss += criterion(outputs, batch_y).item()

        print(f'Epoch {epoch+1}/{num_epochs}, Loss: {loss.item():.4f}, Val Loss: {val_loss/len(val_loader):.4f}')
        model.train()

def main():
    hidden_size = 128
    num_layers = 2
    batch_size = 32
    num_epochs = 50
    learning_rate = 0.001

    folder_path = '/content/drive/MyDrive/gloss_selected'  # Replace with your folder path
    save_path = '/content/drive/MyDrive/gloss_selected'

    # Create save directory if it doesn't exist
    os.makedirs(save_path, exist_ok=True)

    glosses, keypoints, label_encoder = load_data(folder_path)

    # Use the actual input size from the data
    input_size = keypoints.shape[1]
    output_size = keypoints.shape[1]

    # Convert glosses to one-hot encoding
    num_classes = len(label_encoder.classes_)
    glosses_one_hot = np.eye(num_classes)[glosses]

    X_train, X_test, y_train, y_test = train_test_split(glosses_one_hot, keypoints, test_size=0.2, random_state=42)

    train_dataset = SignLanguageDataset(torch.FloatTensor(X_train), torch.FloatTensor(y_train))
    test_dataset = SignLanguageDataset(torch.FloatTensor(X_test), torch.FloatTensor(y_test))
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=batch_size)

    # Modify this line to correctly reflect the number of classes as the input size
    model = GRUSeq2Seq(num_classes, hidden_size, output_size, num_layers)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.to(device)

    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs, device)

    # Save the model
    model_save_path = os.path.join(save_path, 'sign_language_gru_model.pth')
    torch.save(model.state_dict(), model_save_path)
    print(f"Model saved successfully at {model_save_path}")

    # Save the label encoder
    encoder_save_path = os.path.join(save_path, 'label_encoder.pkl')
    with open(encoder_save_path, 'wb') as f:
        pickle.dump(label_encoder, f)
    print(f"Label encoder saved successfully at {encoder_save_path}")

if __name__ == "__main__":
    main()
# Out:
# Loading CSV files: 100%|██████████| 2029/2029 [00:28<00:00, 70.99it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-14-fd1103002ba6> in <cell line: 154>()
#     153
#     154 if __name__ == "__main__":
# --> 155     main()
#
# <ipython-input-14-fd1103002ba6> in main()
#     139     optimizer = optim.Adam(model.parameters(), lr=learning_rate)
#     140
# --> 141     train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs, device)
#     142
#     143     # Save the model
#
# <ipython-input-14-fd1103002ba6> in train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device)
#      84
#      85             optimizer.zero_grad()
# ---> 86             outputs = model(batch_x, batch_y.size(1))
#      87             loss = criterion(outputs, batch_y)
#      88             loss.backward()
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# <ipython-input-14-fd1103002ba6> in forward(self, x, target_len)
#      37
#      38         for _ in range(target_len):
# ---> 39             output, hidden = self.decoder(input, hidden)
#      40             output = self.fc(output)
#      41             outputs.append(output)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#    1135                 hx = self.permute_hidden(hx, sorted_indices)
#    1136
# -> 1137         self.check_forward_args(input, hx, batch_sizes)
#    1138         if batch_sizes is None:
#    1139             result = _VF.gru(input, hx, self._flat_weights, self.bias, self.num_layers,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py in check_forward_args(self, input, hidden, batch_sizes)
#     278
#     279     def check_forward_args(self, input: Tensor, hidden: Tensor, batch_sizes: Optional[Tensor]):
# --> 280         self.check_input(input, batch_sizes)
#     281         expected_hidden_size = self.get_expected_hidden_size(input, batch_sizes)
#     282
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/rnn.py in check_input(self, input, batch_sizes)
#     244                 f'input must have {expected_input_dim} dimensions, got {input.dim()}')
#     245         if self.input_size != input.size(-1):
# --> 246             raise RuntimeError(
#     247                 f'input.size(-1) must be equal to input_size. Expected {self.input_size}, got {input.size(-1)}')
#     248
#
# RuntimeError: input.size(-1) must be equal to input_size. Expected 128, got 99

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer, BertModel
import json
import os
from tqdm import tqdm
from torch.nn.utils.rnn import pad_sequence
import glob

class GlossToKeypointsDataset:
    def __init__(self, data_dir):
        """
        data_dir: Directory containing CSV files named as 'gloss.csv'
        """
        self.data_dir = data_dir
        # Initialize BERT tokenizer for word embeddings
        self.tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
        self.bert = BertModel.from_pretrained('bert-base-uncased')

        # Load and process all data
        self.gloss_to_sequences = {}
        self.load_all_data()

    def load_all_data(self):
        """Load all CSV files and organize data by gloss"""
        print("Loading data from CSV files...")
        csv_files = glob.glob(os.path.join(self.data_dir, "*.csv"))

        for csv_file in tqdm(csv_files):
            # Get gloss from filename
            gloss = os.path.basename(csv_file).replace('.csv', '')

            try:
                # Read keypoints from CSV
                df = pd.read_csv(csv_file)
                sequences = []

                for _, row in df.iterrows():
                    keypoints = json.loads(row['keypoints'])['pose']
                    # Flatten the 3D keypoints array
                    flat_keypoints = np.array(keypoints).flatten()
                    sequences.append(flat_keypoints)

                if sequences:  # Only add if we got valid sequences
                    self.gloss_to_sequences[gloss] = np.array(sequences)

            except Exception as e:
                print(f"Error processing {gloss}: {str(e)}")

        print(f"Successfully loaded {len(self.gloss_to_sequences)} gloss sequences")

    def get_word_embedding(self, word):
        """Get BERT embedding for a word"""
        with torch.no_grad():
            inputs = self.tokenizer(word, return_tensors="pt", padding=True, truncation=True)
            outputs = self.bert(**inputs)
            # Use the [CLS] token embedding as word representation
            return outputs.last_hidden_state[:, 0, :].squeeze(0)

    def prepare_data_loader(self, batch_size=32, train_split=0.8):
        """Prepare train and validation data loaders"""
        # Prepare dataset entries
        all_glosses = list(self.gloss_to_sequences.keys())
        dataset_entries = []

        for gloss in all_glosses:
            word_embedding = self.get_word_embedding(gloss)
            keypoint_sequence = torch.FloatTensor(self.gloss_to_sequences[gloss])
            dataset_entries.append((word_embedding, keypoint_sequence))

        # Split into train and validation
        train_size = int(len(dataset_entries) * train_split)
        train_entries = dataset_entries[:train_size]
        val_entries = dataset_entries[train_size:]

        # Create data loaders
        train_loader = DataLoader(train_entries, batch_size=batch_size,
                                shuffle=True, collate_fn=self.collate_fn)
        val_loader = DataLoader(val_entries, batch_size=batch_size,
                              shuffle=False, collate_fn=self.collate_fn)

        return train_loader, val_loader

    @staticmethod
    def collate_fn(batch):
        """Custom collate function to handle variable length sequences"""
        word_embeddings, sequences = zip(*batch)
        word_embeddings = torch.stack(word_embeddings)
        # Pad sequences to same length
        sequences = pad_sequence(sequences, batch_first=True)
        return word_embeddings, sequences

class KeypointGenerator(nn.Module):
    def __init__(self, embedding_dim=768, hidden_dim=512, pose_dim=96):
        super().__init__()

        self.sequence_generator = nn.Sequential(
            # Process word embedding
            nn.Linear(embedding_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(0.2),

            # Hidden layers
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(0.2),

            # Output layer for pose dimension
            nn.Linear(hidden_dim, hidden_dim),
            nn.ReLU()
        )

        # LSTM for sequence generation
        self.lstm = nn.LSTM(
            input_size=hidden_dim,
            hidden_size=hidden_dim,
            num_layers=2,
            dropout=0.2,
            batch_first=True,
            bidirectional=True
        )

        # Final pose generator
        self.pose_generator = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(hidden_dim, pose_dim)
        )

    def forward(self, word_embedding, seq_length):
        batch_size = word_embedding.size(0)

        # Generate initial sequence representation
        sequence_features = self.sequence_generator(word_embedding)

        # Repeat for desired sequence length
        sequence_features = sequence_features.unsqueeze(1).repeat(1, seq_length, 1)

        # Generate sequence through LSTM
        lstm_out, _ = self.lstm(sequence_features)

        # Generate final pose sequence
        poses = self.pose_generator(lstm_out)

        return poses

def train_model(model, train_loader, val_loader, num_epochs=100):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = model.to(device)

    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    scheduler = torch.optim.ReduceLROnPlateau(optimizer, mode='min', patience=5)

    best_val_loss = float('inf')

    for epoch in range(num_epochs):
        # Training
        model.train()
        train_loss = 0

        for word_embeddings, target_sequences in train_loader:
            word_embeddings = word_embeddings.to(device)
            target_sequences = target_sequences.to(device)

            optimizer.zero_grad()

            # Generate poses
            pred_sequences = model(word_embeddings, target_sequences.size(1))
            loss = criterion(pred_sequences, target_sequences)

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

            train_loss += loss.item()

        avg_train_loss = train_loss / len(train_loader)

        # Validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for word_embeddings, target_sequences in val_loader:
                word_embeddings = word_embeddings.to(device)
                target_sequences = target_sequences.to(device)

                pred_sequences = model(word_embeddings, target_sequences.size(1))
                loss = criterion(pred_sequences, target_sequences)
                val_loss += loss.item()

        avg_val_loss = val_loss / len(val_loader)
        scheduler.step(avg_val_loss)

        print(f'Epoch [{epoch+1}/{num_epochs}], Train Loss: {avg_train_loss:.4f}, Val Loss: {avg_val_loss:.4f}')

        # Save best model
        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            torch.save(model.state_dict(), 'best_keypoint_generator.pth')

def generate_for_new_gloss(model, dataset, gloss, seq_length=30):
    """Generate keypoint sequence for any gloss word"""
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()

    # Get word embedding for the new gloss
    word_embedding = dataset.get_word_embedding(gloss)
    word_embedding = word_embedding.unsqueeze(0).to(device)

    # Generate sequence
    with torch.no_grad():
        generated_sequence = model(word_embedding, seq_length)

    return generated_sequence.cpu().numpy()

def main():
    # Initialize dataset
    dataset = GlossToKeypointsDataset("/content/drive/MyDrive/gloss_selected")

    # Get data loaders
    train_loader, val_loader = dataset.prepare_data_loader(batch_size=32)

    # Initialize and train model
    model = KeypointGenerator()
    train_model(model, train_loader, val_loader)

    # Example: Generate sequence for a new gloss
    new_gloss = "hello"  # Can be any word, even if not in training set
    generated_sequence = generate_for_new_gloss(model, dataset, new_gloss)
    print(f"Generated sequence shape: {generated_sequence.shape}")

if __name__ == "__main__":
    main()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Loading data from CSV files...
# 100%|██████████| 2021/2021 [03:39<00:00,  9.19it/s]
# Successfully loaded 2021 gloss sequences
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-1c94da1b7114> in <cell line: 237>()
#     236
#     237 if __name__ == "__main__":
# --> 238     main()
#
# <ipython-input-1-1c94da1b7114> in main()
#     228     # Initialize and train model
#     229     model = KeypointGenerator()
# --> 230     train_model(model, train_loader, val_loader)
#     231
#     232     # Example: Generate sequence for a new gloss
#
# <ipython-input-1-1c94da1b7114> in train_model(model, train_loader, val_loader, num_epochs)
#     155     criterion = nn.MSELoss()
#     156     optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
# --> 157     scheduler = torch.optim.ReduceLROnPlateau(optimizer, mode='min', patience=5)
#     158
#     159     best_val_loss = float('inf')
#
# AttributeError: module 'torch.optim' has no attribute 'ReduceLROnPlateau'
